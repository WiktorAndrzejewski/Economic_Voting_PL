# %%
import pandas as pd

# %%
# Uploading data from Excel file
Average_salary_amount_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Average salary amount.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Average_salary_amount_raw['County'] = Average_salary_amount_raw['Code'].map(code_to_county).combine_first(Average_salary_amount_raw['County'])

# Removing rows with empty values
Average_salary_amount = Average_salary_amount_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
Average_salary_amount = Average_salary_amount[~Average_salary_amount['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Average_salary_amount.drop('Code', axis=1, inplace=True)
# Out:
#                   County  Year Average salary amount
# 3       Powiat bocheński  2005               2016.51
# 5       Powiat bocheński  2007               2421.74
# 9       Powiat bocheński  2011               3128.68
# 13      Powiat bocheński  2015               3464.39
# 17      Powiat bocheński  2019               4289.47
# ...                  ...   ...                   ...
# 7983  Powiat żyrardowski  2005               2427.82
# 7985  Powiat żyrardowski  2007               2726.18
# 7989  Powiat żyrardowski  2011                3487.5
# 7993  Powiat żyrardowski  2015               4003.47
# 7997  Powiat żyrardowski  2019               4745.14
#
# [1905 rows x 3 columns]

# %%
# Uploading data from Excel file
Entities_register_per_10000_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Entities register per 10 000.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Entities_register_per_10000_raw['County'] = Entities_register_per_10000_raw['Code'].map(code_to_county).combine_first(Entities_register_per_10000_raw['County'])

# Removing rows with empty values
Entities_register_per_10000 = Entities_register_per_10000_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
Entities_register_per_10000 = Entities_register_per_10000[~Entities_register_per_10000['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Entities_register_per_10000.drop('Code', axis=1, inplace=True)

Merge_1 = pd.merge(Average_salary_amount, Entities_register_per_10000, on=['County', 'Year'], how='outer')

# %%
# Uploading data from Excel file
Number_of_apartments_per_1000_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of apartments per 1,000.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_apartments_per_1000_raw['County'] = Number_of_apartments_per_1000_raw['Code'].map(code_to_county).combine_first(Number_of_apartments_per_1000_raw['County'])

# Removing rows with empty values
Number_of_apartments_per_1000 = Number_of_apartments_per_1000_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_apartments_per_1000 = Number_of_apartments_per_1000[~Number_of_apartments_per_1000['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_apartments_per_1000.drop('Code', axis=1, inplace=True)

Merge_2 = pd.merge(Merge_1,Number_of_apartments_per_1000, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_divorces_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of divorces.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_divorces_raw['County'] = Number_of_divorces_raw['Code'].map(code_to_county).combine_first(Number_of_divorces_raw['County'])

# Removing rows with empty values
Number_of_divorces = Number_of_divorces_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_divorces = Number_of_divorces[~Number_of_divorces['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_divorces.drop('Code', axis=1, inplace=True)
Merge_3 = pd.merge(Merge_2,Number_of_divorces, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_hospital_beds_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of hospital beds.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_hospital_beds_raw['County'] = Number_of_hospital_beds_raw['Code'].map(code_to_county).combine_first(Number_of_hospital_beds_raw['County'])

# Removing rows with empty values
Number_of_hospital_beds = Number_of_hospital_beds_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
Number_of_hospital_beds = Number_of_hospital_beds[~Number_of_hospital_beds['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_hospital_beds.drop('Code', axis=1, inplace=True)
Merge_4 = pd.merge(Merge_3,Number_of_hospital_beds, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_housing_units_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of housing units.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_housing_units_raw['County'] = Number_of_housing_units_raw['Code'].map(code_to_county).combine_first(Number_of_housing_units_raw['County'])

# Removing rows with empty values
Number_of_housing_units = Number_of_housing_units_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_housing_units = Number_of_housing_units[~Number_of_housing_units['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_housing_units.drop('Code', axis=1, inplace=True)
Merge_5 = pd.merge(Merge_4,Number_of_housing_units, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_marriages_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of marriages.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_marriages_raw['County'] = Number_of_marriages_raw['Code'].map(code_to_county).combine_first(Number_of_marriages_raw['County'])

# Removing rows with empty values
Number_of_marriages = Number_of_marriages_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_marriages = Number_of_marriages[~Number_of_marriages['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_marriages.drop('Code', axis=1, inplace=True)
Merge_6 = pd.merge(Merge_5,Number_of_marriages, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_outpatient_entities_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of outpatient entities.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Updating county names based on codes
Number_of_outpatient_entities_raw['County'] = Number_of_outpatient_entities_raw['Code'].map(code_to_county).combine_first(Number_of_outpatient_entities_raw['County'])

# Removing rows with empty values
Number_of_outpatient_entities = Number_of_outpatient_entities_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_outpatient_entities = Number_of_outpatient_entities[~Number_of_outpatient_entities['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_outpatient_entities.drop('Code', axis=1, inplace=True)

Merge_7 = pd.merge(Merge_6,Number_of_outpatient_entities, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_people_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of people.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Removing rows with empty values
Number_of_people_raw['County'] = Number_of_people_raw['Code'].map(code_to_county).combine_first(Number_of_people_raw['County'])

# Removing rows with empty values
Number_of_people = Number_of_people_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_people = Number_of_people[~Number_of_people['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_people.drop('Code', axis=1, inplace=True)
Merge_8 = pd.merge(Merge_7,Number_of_people, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_social_assistance_centers_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of social assistance centers.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Removing rows with empty values
Number_of_social_assistance_centers_raw['County'] = Number_of_social_assistance_centers_raw['Code'].map(code_to_county).combine_first(Number_of_social_assistance_centers_raw['County'])

# Removing rows with empty values
Number_of_social_assistance_centers = Number_of_social_assistance_centers_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_social_assistance_centers = Number_of_social_assistance_centers[~Number_of_social_assistance_centers['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_social_assistance_centers.drop('Code', axis=1, inplace=True)

Merge_9 = pd.merge(Merge_8,Number_of_social_assistance_centers, on=['County', 'Year'], how = 'outer')

# %%
# Uploading data from Excel file
Number_of_unemployed_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Number of unemployed.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Dictionary mapping codes to county names
Number_of_unemployed_raw['County'] = Number_of_unemployed_raw['Code'].map(code_to_county).combine_first(Number_of_unemployed_raw['County'])

# Removing rows with empty values
Number_of_unemployed = Number_of_unemployed_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Number_of_unemployed = Number_of_unemployed[~Number_of_unemployed['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Number_of_unemployed.drop('Code', axis=1, inplace=True)
Merge_10 = pd.merge(Merge_9,Number_of_unemployed, on=['County', 'Year'], how = 'outer')

Merge_10.to_excel("C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Czynniki ekonomiczne/Merge_10.xlsx")

# %%
# Uploading data from Excel file
Percentage_of_children_cared_for_in_nurseries_raw = pd.read_excel('C:/Users/wandrzejew001/Desktop/Panel Data/Percentage of children cared for in nurseries.xlsx')

# Dictionary mapping codes to county names
code_to_county = {
    1202000: "Powiat brzeski_Malopolskie",
    2402000: "Powiat bielski_Slaskie",
    802000: "Powiat krośnieński_Lubuskie",
    3017000: "Powiat ostrowski_Wielkopolskie",
    3005000: "Powiat grodziski_Wielkopolskie",
    3025000: "Powiat średzki_Wielkopolskie",
    219000: "Powiat świdnicki_Dolnoslaskie",
    218000: "Powiat średzki_Dolnoslaskie",
    1601000: "Powiat brzeski_Opolskie",
    1609000: "Powiat opolski_Opolskie",
    2210000: "Powiat nowodworski_Pomorskie",
    1016000: "Powiat tomaszowski_Lodzkie",
    618000: "Powiat tomaszowski_Lubelskie",
    617000: "Powiat świdnicki_Lubelskie",
    612000: "Powiat opolski_Lubelskie",
    1807000: "Powiat krośnieński_Podkarpackie",
    2003000: "Powiat bielski_Podlaskie",
    1405000: "Powiat grodziski_Mazowieckie",
    1414000: "Powiat nowodworski_Mazowieckie",
    1416000: "Powiat ostrowski_Mazowieckie"
}

# Dictionary mapping codes to county names
Percentage_of_children_cared_for_in_nurseries_raw['County'] = Percentage_of_children_cared_for_in_nurseries_raw['Code'].map(code_to_county).combine_first(Percentage_of_children_cared_for_in_nurseries_raw['County'])

# Removing rows with empty values
Percentage_of_children_cared_for_in_nurseries = Percentage_of_children_cared_for_in_nurseries_raw.dropna(axis=0)

# Removing specific years
years_to_remove = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2006, 2008, 2009, 2010, 2012, 2013, 2014, 2016, 2017, 2018, 2020, 2021, 2022, 2023]
 
Percentage_of_children_cared_for_in_nurseries = Percentage_of_children_cared_for_in_nurseries[~Percentage_of_children_cared_for_in_nurseries['Year'].isin(years_to_remove)]

# Removing the 'Code' column
Percentage_of_children_cared_for_in_nurseries.drop('Code', axis=1, inplace=True)

# %%
# Creating Socioeconomic_panel_data by merging Merge_10 and Percentage_of_children_cared_for_in_nurseries
Socioeconomic_panel_data = pd.merge(Merge_10, Percentage_of_children_cared_for_in_nurseries, on=['County', 'Year'], how='outer')

# Updating County Names: Removing prefixes such as 'Powiat ', 'm. ', 'st. ' from the values in the 'County' column.
Socioeconomic_panel_data['County'] = Socioeconomic_panel_data['County'].str.replace('Powiat ', '').str.replace('m. ', '').str.replace('st. ', '')
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\1307943671.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   Socioeconomic_panel_data['County'] = Socioeconomic_panel_data['County'].str.replace('Powiat ', '').str.replace('m. ', '').str.replace('st. ', '')

# %%
# Uploading data from Excel file
elections_2005 = pd.read_excel('C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Dane PKW/Sejm/2005/wybory_2005_raw.xlsx')

# Adding a Year Column: Adding a new column named 'Year' to indicate the year of the elections.
elections_2005['Year'] = 2005

# Selecting Relevant Columns: Selecting only the relevant columns and storing the result in a new DataFrame.
elections_2005_clean = elections_2005[['Powiat', 'Year', '6 - Prawo i Sprawiedliwość','8 - Platforma Obywatelska', 'Karty wydane (frekwencja)']]

# Renaming Columns: Renaming the columns to have more meaningful names using the rename() method and storing the result in the same DataFrame.
elections_2005_clean.rename(columns={'Powiat':'County', '6 - Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','8 - Platforma Obywatelska': 'Platforma Obywatelska', 'Karty wydane (frekwencja)':'Voter turnout'}, inplace=True)
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\1405744727.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_2005_clean.rename(columns={'Powiat':'County', '6 - Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','8 - Platforma Obywatelska': 'Platforma Obywatelska', 'Karty wydane (frekwencja)':'Voter turnout'}, inplace=True)

# %%
# Uploading data from Excel file
elections_2007 = pd.read_excel('C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Dane PKW/Sejm/2007/elections_2007_raw.xls')

# Adding a Year Column: Adding a new column named 'Year' to indicate the year of the elections.
elections_2007['Year'] = 2007

# Selecting Relevant Columns: Selecting only the relevant columns and storing the result in a new DataFrame.
elections_2007_clean = elections_2007[['Powiat', 'Year', '6 - Prawo i Sprawiedliwość','8 - Platforma Obywatelska', 'Frekw.']]

# Renaming Columns: Renaming the columns to have more meaningful names using the rename() method and storing the result in the same DataFrame.
elections_2007_clean.rename(columns={'Powiat':'County', '6 - Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','8 - Platforma Obywatelska': 'Platforma Obywatelska', 'Frekw.':'Voter turnout'}, inplace=True)
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\3970607313.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_2007_clean.rename(columns={'Powiat':'County', '6 - Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','8 - Platforma Obywatelska': 'Platforma Obywatelska', 'Frekw.':'Voter turnout'}, inplace=True)

# %%
# Uploading data from Excel file
elections_2011 = pd.read_excel('C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Dane PKW/Sejm/2011/elections_2011_raw.xls')

# Adding a Year Column: Adding a new column named 'Year' to indicate the year of the elections.
elections_2011['Year'] = 2011

# Selecting Relevant Columns: Selecting only the relevant and storing the result in a new DataFrame.
elections_2011_clean = elections_2011[['Powiat', 'Year', 'Komitet Wyborczy Prawo i Sprawiedliwość','Komitet Wyborczy Platforma Obywatelska RP','Liczba kart wydanych']]

# Renaming Columns: Renaming the columns to have more meaningful names using the rename() method and storing the result in the same DataFrame.
elections_2011_clean.rename(columns={'Powiat':'County', 'Komitet Wyborczy Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','Komitet Wyborczy Platforma Obywatelska RP': 'Platforma Obywatelska', 'Liczba kart wydanych':'Voter turnout'}, inplace=True)
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\4253104922.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_2011_clean.rename(columns={'Powiat':'County', 'Komitet Wyborczy Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','Komitet Wyborczy Platforma Obywatelska RP': 'Platforma Obywatelska', 'Liczba kart wydanych':'Voter turnout'}, inplace=True)

# %%
# Uploading data from Excel file
elections_2015 = pd.read_excel('C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Dane PKW/Sejm/2015/elections_2015_raw.xls')

# Adding a Year Column: Adding a new column named 'Year' to indicate the year of the elections.
elections_2015['Year'] = 2015

# Selecting Relevant Columns: Selecting only the relevant and storing the result in a new DataFrame.
elections_2015_clean = elections_2015[['Powiat', 'Year', '1 - Komitet Wyborczy Prawo i Sprawiedliwość','2 - Komitet Wyborczy Platforma Obywatelska RP', 'Wydane karty']]

# Renaming Columns: Renaming the columns to have more meaningful names using the rename() method and storing the result in the same DataFrame.
elections_2015_clean.rename(columns={'Powiat':'County', 'Rok':'Year','1 - Komitet Wyborczy Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','2 - Komitet Wyborczy Platforma Obywatelska RP': 'Platforma Obywatelska','Wydane karty':'Voter turnout'}, inplace=True)
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\2918178875.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_2015_clean.rename(columns={'Powiat':'County', 'Rok':'Year','1 - Komitet Wyborczy Prawo i Sprawiedliwość': 'Prawo i Sprawiedliwosc','2 - Komitet Wyborczy Platforma Obywatelska RP': 'Platforma Obywatelska','Wydane karty':'Voter turnout'}, inplace=True)

# %%
# Uploading data from Excel file
elections_2019 = pd.read_excel('C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Dane PKW/Sejm/2019/elections_2019_raw.xlsx')

# Adding a Year Column: Adding a new column named 'Year' to indicate the year of the elections.
elections_2019['Year'] = 2019

# Selecting Relevant Columns: Selecting only the relevant and storing the result in a new DataFrame.
elections_2019_clean = elections_2019[['Powiat', 'Year', 'KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ','KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI', 'Liczba wyborców, którym wydano karty do głosowania']]

# Renaming Columns: Renaming the columns to have more meaningful names using the rename() method and storing the result in the same DataFrame.
elections_2019_clean.rename(columns={'Powiat':'County', 'KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ': 'Prawo i Sprawiedliwosc','KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI': 'Platforma Obywatelska', 'Liczba wyborców, którym wydano karty do głosowania':'Voter turnout'}, inplace=True)
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\546884391.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elections_2019_clean.rename(columns={'Powiat':'County', 'KOMITET WYBORCZY PRAWO I SPRAWIEDLIWOŚĆ': 'Prawo i Sprawiedliwosc','KOALICYJNY KOMITET WYBORCZY KOALICJA OBYWATELSKA PO .N IPL ZIELONI': 'Platforma Obywatelska', 'Liczba wyborców, którym wydano karty do głosowania':'Voter turnout'}, inplace=True)

# %%
# Creating a List of DataFrames: Creating a list called data_frames that contains multiple DataFrames (elections_2005_clean, elections_2007_clean, elections_2011_clean, elections_2015_clean, elections_2019_clean)
data_frames = [elections_2005_clean, elections_2007_clean, elections_2011_clean, elections_2015_clean, elections_2019_clean]

# Concatenating DataFrames: Concatenating the DataFrames from the list data_frames along the rows (axis=0) and storing the result in a new DataFrame called elections.
elections = pd.concat(data_frames, axis=0, join='outer', ignore_index=True)

# Updating County Names: Removing prefixes such as 'Powiat ', 'm. ', 'st. ' from the values in the 'County' column and storing the result back in the same column.
elections['County'] = elections['County'].str.replace('Powiat ', '').str.replace('m. ', '').str.replace('st. ', '')
# Out:
# C:\Users\wandrzejew001\AppData\Local\Temp\ipykernel_43328\4006623562.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   elections['County'] = elections['County'].str.replace('Powiat ', '').str.replace('m. ', '').str.replace('st. ', '')

# %%
# Merging DataFrames: Merging the DataFrame Socioeconomic_panel_data and elections on the columns 'County' and 'Year' and storing the result in the DataFrame final_merge.
final_merge = pd.merge(Socioeconomic_panel_data, elections, on=['County', 'Year'], how='outer')

# List of Values to Remove: Creating a list called values_to_remove that contains the county names or values that you needs to be removed from the 'County' column of the DataFrame final_merge.
values_to_remove = ['cieszyński', 'warszawski', 'jeleniogórski', 'karkonoski', 'Statki', 'Zagranica', 'Statki (Warszawa)', 'Statki (Gdynia)', 'Statki (Gdańsk)', 'statki', 'zagranica', 'Wałbrzych do 2002', 'Wałbrzych od 2013', 'Wałbrzych']

# %%
final_merge.to_excel("C:/Users/wandrzejew001/Desktop/Data Analyse Training/Dane do pracy/Czynniki ekonomiczne/final_merge.xlsx")
